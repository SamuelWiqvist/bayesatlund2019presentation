# %% [markdown]
# # Deep learning and ABC
#
# Samuel Wiqvist, Lund University
#
# Work with: a, b, and c.

# %% [markdown]
# ## First example

# %%
using PyPlot

PyPlot.plot(rand(10),rand(10), "*");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## new section

# %%
a = 5^2
# Out:
# 25

# %% [markdown]
# ## The end
